# %% [markdown]
# # Mini Project 4

# %% [markdown]
# _In the lectures we explored how to delta hedge sold call options, resulting in a trading strategy whose profits are neutral to upward or downward drift in a stock path movements, provided the volatility, or $\sigma$, of the stock remained constant._
#
# _For this final mini project explore the impact of a non-constant $\sigma$ on the distribution of profits of hedging. You are also encouraged to explore/research a $\sigma$-hedging strategy and write code that simulates the profit distribution of the $\sigma$-hedging strategy._
#
# -------------------------
#
# I will simulate the profits of selling a call by modelling a stock path's movement using the _n_-step Heston stochastic volatility model, and using a sigma-hedging strategy whose profits are neutral to variations in the volatility of the stock path. I will do this by taking a position in another option, possibly with differing strikes and expiration times, such that _the overall vega of the the portfolio is zero_. Assuming the drift is constant until time to expiry, the expected final profit of the portfolio will solely be a function of drift (with strike, time to expiration, risk-free rate _r_ and spot price predetermined).
#
# _Note: For the sake of clarity and collating the relevant information, some of the notes regarding the Heston model given below have been taken from the Erdos Institute quant finance lecture notebooks._

# %%
#Package Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

import numpy as np
from scipy.stats import norm
from scipy.optimize import brentq
from scipy.integrate import quad

# %% [markdown]
# ### The $n$-step discrete Heston Model:
#
# Let $0 = t_0<t_1<\cdots <t_n = t$, then the $n$-step discrete Heston model assumes for each $1\leq i\leq n$ the variance of the log-returns at time $t_i$ is modeled as
#
# $$v_{t_i} = |v_{i-1} + \kappa(\theta - v_{t_{i-1}})(t_i-t_{i-1}) + \xi\sqrt{|v_{i-1}|(t_i-t_{i-1})}\mathcal{N}^{v}(0,1)|$$
#
# and the distribution of stock paths from time $t_{i-1}$ to $t_i$ is modeled as
#
# $$S_{t_i} = S_{t_{i-1}}e^{(\mu + r - .5v_{t_{i-1}})(t_i-t_{i-1}) + \sqrt{|v_{t_{i-1}}|(t_i-t_{i-1})}\mathcal{N}^S(0,1)}$$
# where:
#
# - $S_0$ is the initial stock price;
# - $S_t$ is the stock price at time $t$;
# - $v_0$ is the variance of the stock at time $0$;
# - $v_t$ is the variance of the stock at time $t$;
# - $\mu$ is the excess drift of the log-returns of the stock;
# - $r$ is the risk-free interest rate;
# - $\kappa$ is the **mean-reversion rate** of the variance process;
# - $\theta$ is the **long-run variance level** of the variance process;
# - $\xi$ is the **volatility of volatility**
# - $\mathcal{N}^{v}(0,1)$ and $\mathcal{N}^{S}(0,1)$ are standard normal distributions with correlation $\rho$
#
# First, I'll simulate stock paths with the _n_ step Heston model.

# %%
def heston_path_sim(S0, v0, r, t, n_steps, kappa, theta, xi, rho, n_sims=1, mu=0, return_vol=False):
    """
    Simulation of stock path movements under the Heston stochastic volatility model.
    
    Parameters:
    - S0 (float): Initial stock price
    - v0 (float): Initial variance
    - r (float): Risk-free interest rate
    - t (float): Total time horizon (in years)
    - n_steps (int): Number of time steps
    - kappa (float): Rate of mean reversion of variance
    - theta (float): Long-run variance
    - xi (float): Volatility of volatility
    - rho (float): Correlation between Brownian motions
    - n_sims (int): Number of simulated paths
    - mu (float): Excess drift of log-returns
    - return_vol (bool): Whether to return the simulated variance paths

    Returns:
    - paths (ndarray): Simulated stock price paths of shape (n_sims, n_steps + 1)
    - vols (ndarray, optional): Simulated variance paths if return_vol is True
    """
    dt = t / n_steps
    N1 = np.random.normal(0, 1, size=(n_sims, n_steps))
    N2 = np.random.normal(0, 1, size=(n_sims, n_steps))
    Y = rho * N1 + np.sqrt(1 - rho**2) * N2

    paths = np.zeros((n_sims, n_steps + 1))
    variances = np.zeros((n_sims, n_steps + 1))
    paths[:, 0] = S0
    variances[:, 0] = v0

    for i in range(n_steps):
        variances[:, i + 1] = np.abs(variances[:, i] + kappa * (theta - variances[:, i]) * dt +
                                xi * np.sqrt(np.maximum(variances[:, i], 0) * dt) * N1[:, i])
        paths[:, i + 1] = paths[:, i] * np.exp((mu + r - 0.5 * variances[:, i]) * dt +
                                               np.sqrt(np.maximum(variances[:, i], 0) * dt) * Y[:, i])
    
    return (paths, variances) if return_vol else paths


### Visual of stock paths measure simulated through the Heston model

kappa = 2.4 #Mean reversion rate of variance of log-returns (Typical range 1 to 5)

theta = .3**2 #Long run variance of log-returns

xi = .43 # Volatility of Volatility (Typical range .2 to 1)

v0 = .22**2 #Initial variance of log-returns

rho = -.6 #Correlation of random noise of variance and log-returns (Typical range -.9 to -.4)

S0 = 80 #Initial Stock Value

t = 1 #Time horizon

n_steps = 252 #Number of steps in each simulation

r = .039 #Risk-free interest rate

n_sims = 5 #Number of simulations

mu = 0.13 #Excess drift of log returns



heston_paths = heston_path_sim(S0, v0, r, t, n_steps, kappa, theta, xi, rho, n_sims, mu)

plt.figure(figsize = (12,8))
for path in heston_paths:
    plt.plot(path)
    
    
plt.title('Heston Path Simulations', size = 20)

plt.show()

# %% [markdown]
# To set things up, I'll implement a vega hedging strategy in the 1 step Heston model. This will involve both selling and buying a call option contract with the same times to expiration. The sold call has strike $K_2$, and the bought call has strike $K_1$, in such a way that $K_1 = 2S_0 - K_2$. The strategy is then vega neutral because the rate of change in the value of the sold call with respect to volatility is perfectly offset by the rate of change with respect to volatility of the bought call. In symbols, if $X$ is the portfolio, $C_0^1$ is the value at time 0 of the bought call and $C_0^2$ is the value at time 0 of the sold call, then (ignoring premiums / initial cashflow)
#
# $$ X = C_0^1 - C_0^2 \quad \implies \quad \frac{\partial X}{\partial \sigma} = \frac{\partial C_0^1}{\partial \sigma} - \frac{\partial C_0^2}{\partial \sigma} = \nu_{C_0^1} - \nu_{C_0^2} = 0,$$
#
# because $\nu_{C_0^1}=\nu_{C_0^2}$.
#
# There are two types of scenarios to consider:
#
# 1) The 'bear call spread' is when the strike $K_2$ of the sold call satisfies $K_2<S_0$, in which case the long call has strike $K_1 = 2 S_0 - K_2 > S_0$. This strategy has maximum profit when the underlying finishes _at or below_ the lower strike $K_2$, and maximum loss when the underlying finishes _at or above_ the higher strike $K_1$. Thus, to maximise potential profits one should engage in this strategy if and only if the drift $\mu$ of the underlying is _negative_, $\mu<0$, in which case the underlying is more likely to finish lower than $S_0$. Note that the primary instrument in this scenario is the sold (shorted) call and the hedging instrument is the bought (long) call.
#
# 2) The 'bull call spread' is when the strike $K_2$ of the sold call satisfies $K_2>S_0$, in which case the long call has strike $K_1 = 2 S_0 - K_2 < S_0$. This strategy has maximum profit when the underlying finishes _at or above_ the higher strike $K_2$, and maximum loss when the underlying finishes _at or below_ the lower strike $K_1$. Thus, to maximise potential profits one should engage in this strategy if and only if the drift $\mu$ of the underlying is _positive_, $\mu>0$, in which case the underlying is more likely to finish higher than $S_0$. Note that the primary instrument in this scenario is the bought (long) call and the hedging instrument is the sold (short) call.
#
# It should be noted that both strategies have limited risk and limited potential profit; moreover, which strategy to engage is dependent on the sign of the drift $\mu$.

# %%
def one_step_heston_call_MC_vega_hedge(S0, K, v0, r, t, kappa, theta, xi, rho, mu=0, n_sims=2500):
    """
    Monte-Carlo Simulation of Call Option under Heston model with MC Heston vega control variates to mitigate loss due to risk
    
    Parameters:
    - S0 (float): Initial stock price
    - K (float): Strike Price
    - v0 (float): Initial variance
    - r (float): Risk-free interest rate
    - t (float): Total time horizon (in years)
    - n_steps (int): Number of time steps
    - kappa (float): Rate of mean reversion of variance
    - theta (float): Long-run variance
    - xi (float): Volatility of volatility
    - rho (float): Correlation between Brownian motions
    - n_sims (int): Number of simulated paths
    - mu (float): Excess drift of log-returns
    - return_vol (bool): Whether to return the simulated variance paths

    Returns:
    - call_payouts (ndarray): Simulated payouts of a call-option
    """

    spot_prices = np.ones(n_sims)*S0
    
    paths, variances = heston_path_sim(S0, v0, r, t, 1, kappa, theta, xi, rho, n_sims, mu, return_vol=True )

    # Hedge the sold (short) call by entering a long position in a call contract of same expiration ("vertical spread"), 
    # with strike K1 = 2*S0 - K (i.e. such that K1 and K are equidistant from S0, and either K1<S0<K or K<S0<K1.)

    K1 = 2*S0-K
    
    # Long call payouts
    
    long_call_payouts = np.maximum(paths[:, -1] - K1, 0) * np.exp(-r * t)

    # Short call payouts
    
    short_call_payouts = np.maximum(paths[:, -1] - K, 0) * np.exp(-r * t)

    # Adjusted final payout of the overall position / portfolio:
    
    # call_payouts_hedged = short_call_payouts - long_call_payouts # final payout (outflow) of the overall position
                                                                 # (positive -> loss, negative --> gain)

    call_payouts_hedged = long_call_payouts - short_call_payouts  # final payout (inflow) of the overall position 
                                                                # (positive -> gain, negative -> loss)
    
    return call_payouts_hedged

# %% [markdown]
# Now to simulate the value of this hedging strategy in the following cases (recall $K_2$ is the strike of the sold call and $K_1$ the strike of the bought call):
#
# 1) Bear call spread $(K_2<S_0<K_1)$. Min value: $K_2 - K_1<0$ (when $S_t < K_2$), max value: $0$ (when $S_t > K_1$).
# 2) Bull call spread $(K_1<S_0<K_2)$. Min value: $0$ (when $S_t < K_1$), max value: $K_2 - K_1>0$ (when $S_t > K_2$).
#
# Note that I am ignoring the initial cashflow / premiums collected and paid from selling and buying the two calls, and only plotting the _final value/payout of the position_, where positive values correspond to a gain and negative to a loss. The values are discounted to time zero. For the purposes of this notebook, I will ignore the scenario when $S_0=K_2=K_1$.
#
# I will consider each of case 1 and 2 above when $\mu<0$ and $\mu>0$ (4 cases in total). Recall that in the bear call spread the primary instrument is the sold call and the long call is the hedge, while in the bull call the primary instrument is the long call and the short call is the hedge.

# %%
# Use Monte-Carlo methods to simulate price of call option under 1-step Heston-Model with a vega hedge

# CASE 1: Bear call spread with K2 < S0 < K1 and mu<0 (negative excess drift)

# Important parameters:

mu = -0.13  # Excess drift of log returns

K2 = 57  # strike of sold call (primary instrument)

S0 = 60 # Initial Stock Value

K1 = 2*S0 - K2 # strike of long call (hedging instrument)


# Other Heston parameters

kappa = 2.4 # Mean reversion rate of variance of log-returns (Typical range 1 to 5)

theta = .3**2 # Long run variance of log-returns

xi = .2 # Volatility of Volatility (Typical range .2 to 1)

v0 = .18**2 # Initial variance of log-returns

rho = -.6 # Correlation of random noise of variance and log-returns (Typical range -.9 to -.4)

t = 14/365 # Time horizon

r = .039 # Risk-free interest rate

n_sims = 10000 # Number of simulations



# Monte-Carlo Simulation of final value of overall position

call_payouts_hedged = one_step_heston_call_MC_vega_hedge(S0, K2, v0, r, t, kappa, theta, xi, rho, mu=mu, n_sims=n_sims)

heston_call_sim = np.mean(np.mean(call_payouts_hedged))

heston_std_err = np.std(call_payouts_hedged)/np.sqrt(n_sims)


print(f'Heston Monte-Carlo Simulated value of overall position / payout with \
{n_sims} simulations: ${heston_call_sim:.2f} with standard error {heston_std_err:.6f}.')

print(f'Thus, if P1 is the premium paid for the long call, and P2 is the premium collected for the short call, the initial cashflow is P2-P1,\
 and in order to expect to make a profit from the portfolio, considering the average final payout one needs to ensure that P2-P1 > ${heston_call_sim:.2f}.')



print('-----'*10)
print('-----'*10)



plt.figure(figsize = (8,6))
plt.hist(call_payouts_hedged, bins = 75, color = 'pink', alpha = .8, label = 'Simulated Heston Call Prices with 1 vega hedge')
#plt.axvline(heston_call_price, label = 'Heston Call Price',color = 'black', lw = '7', alpha = 1)
plt.axvline(heston_call_sim, label = 'Mean simulated Price', color = 'red', ls = '--')
plt.title(f'Simulated value of overall (hedged) position, 1-step Heston Model with {n_sims} simulations', size = 15)
plt.legend()
plt.show()

print('-----'*10)
print('-----'*10)


# Now simulate the distribution of the value of either spread with no hedging.

# Final value of the position with no hedge, i.e. only the sold / shorted call and no long call

heston_no_hedging = -np.maximum(heston_path_sim(S0, v0, r, t, 1, kappa, theta, xi, rho, n_sims, mu, return_vol=False )  - K2, 0) * np.exp(-r * t)

# Compute mean and SE of values above
mm=np.mean(heston_no_hedging[:,-1])
se=np.std(heston_no_hedging[:,-1])/np.sqrt(n_sims)
maxloss=np.min(heston_no_hedging[:,-1])

print(f'Heston Monte-Carlo Simulated value of position with no hedge \
and {n_sims} simulations: ${mm:.2f} and standard error {se:.4f}.\
The max payout/loss is ${maxloss:.2f}; by comparison, the max loss of the hedged portfolio is ${K2-K1}.')


print('-----'*10)
print('-----'*10)


plt.figure(figsize = (8,6))
plt.hist(heston_no_hedging[:,-1], bins = 75, color = 'pink', alpha = .8, label = 'Simulated Heston Call Prices with no hedging')
plt.title(f'Simulated value of sold call in 1-step Heston Model with no hedge and {n_sims} simulations', size = 15)
plt.axvline(mm, label = 'Mean simulated Price', color = 'red', ls = '--')
plt.axvline(maxloss, label = 'Max loss', color = 'blue', ls = '--')
plt.legend()
plt.show()
# Out:
# Heston Monte-Carlo Simulated value of overall position / payout with 10000 simulations: $-2.81 with standard error 0.018370.
# Thus, if P1 is the premium paid for the long call, and P2 is the premium collected for the short call, the initial cashflow is P2-P1, and in order to expect to make a profit from the portfolio, considering the average final payout one needs to ensure that P2-P1 > $-2.81.
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# Heston Monte-Carlo Simulated value of position with no hedge and 10000 simulations: $-2.89 and standard error 0.0197.The max payout/loss is $-11.32; by comparison, the max loss of the hedged portfolio is $-6.
# --------------------------------------------------
# --------------------------------------------------

# %%
# CASE 2: Bear call spread with K2 < S0 < K1 and mu>0 (positive excess drift)

# Important parameters:

mu = 0.21  # Excess drift of log returns

K2 = 57  # strike of sold call (primary instrument)

S0 = 60 # Initial Stock Value

K1 = 2*S0 - K2 # strike of long call (hedging instrument)


# Other Heston parameters

kappa = 2.4 # Mean reversion rate of variance of log-returns (Typical range 1 to 5)

theta = .3**2 # Long run variance of log-returns

xi = .2 # Volatility of Volatility (Typical range .2 to 1)

v0 = .18**2 # Initial variance of log-returns

rho = -.6 # Correlation of random noise of variance and log-returns (Typical range -.9 to -.4)

t = 14/365 # Time horizon

r = .039 # Risk-free interest rate

n_sims = 10000 # Number of simulations



# Monte-Carlo Simulation of final value of overall position

call_payouts_hedged = one_step_heston_call_MC_vega_hedge(S0, K2, v0, r, t, kappa, theta, xi, rho, mu=mu, n_sims=n_sims)

heston_call_sim = np.mean(np.mean(call_payouts_hedged))

heston_std_err = np.std(call_payouts_hedged)/np.sqrt(n_sims)


print(f'Heston Monte-Carlo Simulated value of overall position / payout with \
{n_sims} simulations: ${heston_call_sim:.2f} with standard error {heston_std_err:.6f}.')

print(f'Thus, if P1 is the premium paid for the long call, and P2 is the premium collected for the short call, the initial cashflow is P2-P1,\
 and in order to expect to make a profit from the portfolio, considering the average final payout one needs to ensure that P2-P1 > ${heston_call_sim:.2f}.')



print('-----'*10)
print('-----'*10)



plt.figure(figsize = (8,6))

plt.hist(call_payouts_hedged, bins = 75, color = 'pink', alpha = .8, label = 'Simulated Heston Call Prices with 1 vega hedge')
#plt.axvline(heston_call_price, label = 'Heston Call Price',color = 'black', lw = '7', alpha = 1)
plt.axvline(heston_call_sim, label = 'Mean simulated Price', color = 'red', ls = '--')
plt.title(f'Simulated value of overall (hedged) position, 1-step Heston Model with {n_sims} simulations', size = 15)
plt.legend()
plt.show()

print('-----'*10)
print('-----'*10)


# Now simulate the distribution of the value of either spread with no hedging.

# Final value of the position with no hedge, i.e. only the sold / shorted call and no long call

heston_no_hedging = -np.maximum(heston_path_sim(S0, v0, r, t, 1, kappa, theta, xi, rho, n_sims, mu, return_vol=False )  - K2, 0) * np.exp(-r * t)

# Compute mean and SE of values above
mm=np.mean(heston_no_hedging[:,-1])
se=np.std(heston_no_hedging[:,-1])/np.sqrt(n_sims)
maxloss=np.min(heston_no_hedging[:,-1])

print(f'Heston Monte-Carlo Simulated value of position with no hedge \
and {n_sims} simulations: ${mm:.2f} and standard error {se:.4f}. \
The max payout/loss is ${maxloss:.2f}; by comparison, the max loss of the hedged portfolio is ${K2-K1}.')


print('-----'*10)
print('-----'*10)


plt.figure(figsize = (8,6))
plt.hist(heston_no_hedging[:,-1], bins = 75, color = 'pink', alpha = .8, label = 'Simulated Heston Call Prices with no hedging')
plt.title(f'Simulated value of sold call in 1-step Heston Model with no hedge and {n_sims} simulations', size = 15)
plt.axvline(mm, label = 'Mean simulated Price', color = 'red', ls = '--')
plt.axvline(maxloss, label = 'Max loss', color = 'blue', ls = '--')
plt.legend()
plt.show()
# Out:
# Heston Monte-Carlo Simulated value of overall position / payout with 10000 simulations: $-3.50 with standard error 0.017940.
# Thus, if P1 is the premium paid for the long call, and P2 is the premium collected for the short call, the initial cashflow is P2-P1, and in order to expect to make a profit from the portfolio, considering the average final payout one needs to ensure that P2-P1 > $-3.50.
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# Heston Monte-Carlo Simulated value of position with no hedge and 10000 simulations: $-3.59 and standard error 0.0207. The max payout/loss is $-13.66; by comparison, the max loss of the hedged portfolio is $-6.
# --------------------------------------------------
# --------------------------------------------------

# %%
# CASE 3: Bull call spread with K1 < S0 < K2 and mu>0 (positive excess drift)

# Important parameters:

mu = 0.32  # Excess drift of log returns

K2 = 64  # strike of sold call (hedging instrument)

S0 = 60 # Initial Stock Value

K1 = 2*S0 - K2 # strike of long call (primary instrument)

# Other Heston parameters

kappa = 2.4 # Mean reversion rate of variance of log-returns (Typical range 1 to 5)

theta = .3**2 # Long run variance of log-returns

xi = .2 # Volatility of Volatility (Typical range .2 to 1)

v0 = .18**2 # Initial variance of log-returns

rho = -.6 # Correlation of random noise of variance and log-returns (Typical range -.9 to -.4)

t = 14/365 # Time horizon

r = .039 # Risk-free interest rate

n_sims = 10000 # Number of simulations



# Monte-Carlo Simulation of final value of overall position

call_payouts_hedged = one_step_heston_call_MC_vega_hedge(S0, K2, v0, r, t, kappa, theta, xi, rho, mu=mu, n_sims=n_sims)

heston_call_sim = np.mean(np.mean(call_payouts_hedged))

heston_std_err = np.std(call_payouts_hedged)/np.sqrt(n_sims)


print(f'Heston Monte-Carlo Simulated value of overall position / payout with \
{n_sims} simulations: ${heston_call_sim:.2f} with standard error {heston_std_err:.6f}.')

print(f'Thus, if P1 is the premium paid for the long call, and P2 is the premium collected for the short call, the initial cashflow is P2-P1,\
 and in order to expect to make a profit from the portfolio, considering the average final payout one needs to ensure that P2-P1 > ${heston_call_sim:.2f}.')



print('-----'*10)
print('-----'*10)



plt.figure(figsize = (8,6))

plt.hist(call_payouts_hedged, bins = 75, color = 'pink', alpha = .8, label = 'Simulated Heston Call Prices with 1 vega hedge')
plt.axvline(heston_call_sim, label = 'Mean simulated Price', color = 'red', ls = '--')
plt.title(f'Simulated value of overall (hedged) position, 1-step Heston Model with {n_sims} simulations', size = 15)
plt.legend()
plt.show()

print('-----'*10)
print('-----'*10)


# Now simulate the distribution of the value of either spread with no hedging

# Final value of the position with no hedge, i.e. only the bought / long call and no sold / short call

heston_no_hedging = np.maximum(heston_path_sim(S0, v0, r, t, 1, kappa, theta, xi, rho, n_sims, mu, return_vol=False )  - K1, 0) * np.exp(-r * t)

# Compute mean and SE of values above

mm=np.mean(heston_no_hedging[:,-1])
se=np.std(heston_no_hedging[:,-1])/np.sqrt(n_sims)

print(f'Heston Monte-Carlo Simulated value of position with no hedge \
and {n_sims} simulations: ${mm:.2f} and standard error {se:.4f}.')


print('-----'*10)
print('-----'*10)


plt.figure(figsize = (8,6))
plt.hist(heston_no_hedging[:,-1], bins = 75, color = 'pink', alpha = .8, label = 'Simulated Heston Call Prices with no hedging')
plt.title(f'Simulated value of bought call in 1-step Heston Model with no hedge and {n_sims} simulations', size = 15)
plt.axvline(mm, label = 'Mean simulated Price', color = 'red', ls = '--')
plt.axvline(maxloss, label = 'Max loss', color = 'blue', ls = '--')
plt.legend()
plt.show()
# Out:
# Heston Monte-Carlo Simulated value of overall position / payout with 10000 simulations: $4.74 with standard error 0.019932.
# Thus, if P1 is the premium paid for the long call, and P2 is the premium collected for the short call, the initial cashflow is P2-P1, and in order to expect to make a profit from the portfolio, considering the average final payout one needs to ensure that P2-P1 > $4.74.
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# Heston Monte-Carlo Simulated value of position with no hedge and 10000 simulations: $4.85 and standard error 0.0212.
# --------------------------------------------------
# --------------------------------------------------

# %%
# CASE 4: Bull call spread with K1 < S0 < K2 and mu<0 (negative excess drift)

# Important parameters:

mu = -0.15  # Excess drift of log returns

K2 = 64  # strike of sold call (hedging instrument)

S0 = 60 # Initial Stock Value

K1 = 2*S0 - K2 # strike of long call (primary instrument)

# Other Heston parameters

kappa = 2.4 # Mean reversion rate of variance of log-returns (Typical range 1 to 5)

theta = .3**2 # Long run variance of log-returns

xi = .2 # Volatility of Volatility (Typical range .2 to 1)

v0 = .18**2 # Initial variance of log-returns

rho = -.6 # Correlation of random noise of variance and log-returns (Typical range -.9 to -.4)

t = 14/365 # Time horizon

r = .039 # Risk-free interest rate

n_sims = 10000 # Number of simulations



# Monte-Carlo Simulation of final value of overall position

call_payouts_hedged = one_step_heston_call_MC_vega_hedge(S0, K2, v0, r, t, kappa, theta, xi, rho, mu=mu, n_sims=n_sims)

heston_call_sim = np.mean(np.mean(call_payouts_hedged))

heston_std_err = np.std(call_payouts_hedged)/np.sqrt(n_sims)


print(f'Heston Monte-Carlo Simulated value of overall position / payout with \
{n_sims} simulations: ${heston_call_sim:.2f} with standard error {heston_std_err:.6f}.')

print(f'Thus, if P1 is the premium paid for the long call, and P2 is the premium collected for the short call, the initial cashflow is P2-P1,\
 and in order to expect to make a profit from the portfolio, considering the average final payout one needs to ensure that P2-P1 > ${heston_call_sim:.2f}.')



print('-----'*10)
print('-----'*10)



plt.figure(figsize = (8,6))

plt.hist(call_payouts_hedged, bins = 75, color = 'pink', alpha = .8, label = 'Simulated Heston Call Prices with 1 vega hedge')
plt.axvline(heston_call_sim, label = 'Mean simulated Price', color = 'red', ls = '--')
plt.title(f'Simulated value of overall (hedged) position, 1-step Heston Model with {n_sims} simulations', size = 15)
plt.legend()
plt.show()

print('-----'*10)
print('-----'*10)


# Now simulate the distribution of the value of either spread with no hedging

# Final value of the position with no hedge, i.e. only the bought / long call and no sold / short call

heston_no_hedging = np.maximum(heston_path_sim(S0, v0, r, t, 1, kappa, theta, xi, rho, n_sims, mu, return_vol=False )  - K1, 0) * np.exp(-r * t)

# Compute mean and SE of values above

mm=np.mean(heston_no_hedging[:,-1])
se=np.std(heston_no_hedging[:,-1])/np.sqrt(n_sims)

print(f'Heston Monte-Carlo Simulated value of position with no hedge \
and {n_sims} simulations: ${mm:.2f} and standard error {se:.4f}.')


print('-----'*10)
print('-----'*10)


plt.figure(figsize = (8,6))
plt.hist(heston_no_hedging[:,-1], bins = 75, color = 'pink', alpha = .8, label = 'Simulated Heston Call Prices with no hedging')
plt.title(f'Simulated value of bought call in 1-step Heston Model with no hedge and {n_sims} simulations', size = 15)
plt.axvline(mm, label = 'Mean simulated Price', color = 'red', ls = '--')
plt.legend()
plt.show()
# Out:
# Heston Monte-Carlo Simulated value of overall position / payout with 10000 simulations: $3.75 with standard error 0.019908.
# Thus, if P1 is the premium paid for the long call, and P2 is the premium collected for the short call, the initial cashflow is P2-P1, and in order to expect to make a profit from the portfolio, considering the average final payout one needs to ensure that P2-P1 > $3.75.
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# Heston Monte-Carlo Simulated value of position with no hedge and 10000 simulations: $3.76 and standard error 0.0205.
# --------------------------------------------------
# --------------------------------------------------

# %% [markdown]
# ## Simulating vega
#
# Below I simulate the value of vega in the 1 step Heston model using Monte Carlo simulations. While this is not necessary for the above simulations, the below code can be generalised to the $n$-step Heston model. In this case, the value of vega $\nu_{X,t_n}$ of the overall portfolio $X$ can be computed at each timestep $t_n$, and one takes a position in an additional option contract whose vega is $-\nu_{X,t_n}$. Doing so at each timestep _before_ the expiration date ensures the overall vega of the portfolio alwasy remains neutral / zero.

# %%
def heston_MC_vega(S0, v0, r, t, kappa, theta, xi, rho, mu=0, n_sims=2500):

    """
    Monte Carlo simulation of 1-step Heston vega
    
    Parameters:
    - S0 (float): Initial stock price
    - v0 (float): Initial variance
    - r (float): Risk-free interest rate
    - t (float): Total time horizon (in years)
    - n_steps (int): Number of time steps
    - kappa (float): Rate of mean reversion of variance
    - theta (float): Long-run variance
    - xi (float): Volatility of volatility
    - rho (float): Correlation between Brownian motions
    - n_sims (int): Number of simulated paths
    - mu (float): Excess drift of log-returns
    - return_vol (bool): Whether to return the simulated variance paths

    Returns:
        float: Vega of Call and Put Option
    """
    sigma = np.sqrt(v0)
    bump = .01*sigma # epsilon

    N1 = np.random.normal(0, 1, n_sims)
    N2 = np.random.normal(0, 1, n_sims)
    Y = rho * N1 + np.sqrt(1 - rho**2) * N2

    sigma_plus_epsilon = sigma + bump
    sigma_minus_epsilon = sigma - bump
    
    paths_up = S0 * np.exp((mu + r - 0.5 * (sigma + bump)**2) * t + np.sqrt(np.maximum((sigma + bump)**2, 0) * t) * Y) # substituted (sigma + epsilon)^2 for v0 
    paths_down = S0 * np.exp((mu + r - 0.5 * (sigma - bump)**2) * t + np.sqrt(np.maximum((sigma - bump)**2, 0) * t) * Y) # substituted (sigma - epsilon)^2 for v0

    calls_up = np.maximum(paths_up - K, 0)*np.exp(-r*t)
    calls_down = np.maximum(paths_down - K, 0)*np.exp(-r*t)

    vega_sims = (calls_up - calls_down)/(2*bump)

    vega_estimate = np.mean(vega_sims)

    return vega_estimate
    


def heston_MC_vega_array(spot_prices, v0, r, t, kappa, theta, xi, rho, mu=0, n_sims=2500):

    """
    Monte Carlo simulation of 1-step Heston vega
    
    Parameters:
    - S0 (np.array of floats): spot prices
    - v0 (float): Initial variance
    - r (float): Risk-free interest rate
    - t (float): Total time horizon (in years)
    - n_steps (int): Number of time steps
    - kappa (float): Rate of mean reversion of variance
    - theta (float): Long-run variance
    - xi (float): Volatility of volatility
    - rho (float): Correlation between Brownian motions
    - n_sims (int): Number of simulated paths
    - mu (float): Excess drift of log-returns
    - return_vol (bool): Whether to return the simulated variance paths

     Returns:
        float: array of Vegas of Call and Put Options with initial prices S0
    """

    sigma = np.sqrt(v0)
    bump = .001*sigma # epsilon

    N1 = np.random.normal(0, 1, (n_sims,len(spot_prices)))
    N2 = np.random.normal(0, 1, (n_sims,len(spot_prices)))
    Y = rho * N1 + np.sqrt(1 - rho**2) * N2

    sigma_plus_epsilon = sigma + bump
    sigma_minus_epsilon = sigma - bump

    paths_up = spot_prices * np.exp((mu + r - 0.5 * (sigma + bump)**2) * t + np.sqrt(np.maximum((sigma + bump)**2, 0) * t) * Y[:, 0]) # substituted (sigma + epsilon)^2 for v0 
    paths_down = spot_prices * np.exp((mu + r - 0.5 * (sigma - bump)**2) * t + np.sqrt(np.maximum((sigma - bump)**2, 0) * t) * Y[:, 0]) # substituted (sigma - epsilon)^2 for v0

    calls_up = np.maximum(paths_up - K, 0)*np.exp(-r*t)
    calls_down = np.maximum(paths_down - K, 0)*np.exp(-r*t)

    vega_sims = (calls_up - calls_down)/(2*bump)

    vega_estimate = np.mean(vega_sims, axis=0)

    return vega_estimate # returns an array / row

# %% [markdown]
# ### References
#
# The vega-neutral strategy of buying options contracts was taken from the following sources:
#
# - https://www.macroption.com/bear-call-spread/#strike-selection
# - Section 9.1.3. of Mathematics for Finance: An introduction to financial engineering, _Marek Capinski, Tomasz Zastawniak_.
